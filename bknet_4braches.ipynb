# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My\ Drive/rubik_project
# Out:
# /content/gdrive/My Drive/rubik_project

# %%
# !nvidia-smi
# Out:
# Sat Jan 18 15:33:06 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.44       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import numpy as np
import cv2
import PIL
import imutils

# %%
import data_provider

dataset = data_provider.Dataset(data_type='public_test', batch_size=64)
print(len(dataset.all_data))

# assert len(dataset.all_data) == 15648

for i in range(len(dataset.all_data)):
    label = np.squeeze(np.array(dataset.all_data[i][1]))
    index = dataset.all_data[i][2]

    assert np.sum(label) == 1
    
    assert index == 1.0 or index == 2.0 or index == 3.0 or index == 4.0
    assert label.shape == (7,)
# Out:
# Load smile image...................
# Done !
# Number of smile train data:  3000
# ---------------------------------------------------------------
# Load emotion image..................
# Done !
# Number of emotion train data:  28709
# ---------------------------------------------------------------
# Load gender image...................
# Done !
# Number of gender train data:  30000
# ---------------------------------------------------------------
# Load age image..................
# Done !
# Number of age train data:  27353
# ---------------------------------------------------------------
# 15648

# %%
dataset = data_provider.Dataset(data_type='public_test', batch_size=1000)
cnt = 0
for batch_images, batch_labels, batch_indexes in dataset.gen():
    cnt += 1
    n = len(batch_images)
    m = len(batch_labels)
    k = len(batch_indexes)
    print(cnt, n, m, k)
    assert n == m == k
    if cnt % 16 == 0:
        assert n == 648
    else:
        assert n == 1000
# Out:
# Load smile image...................
# Done !
# Number of smile train data:  3000
# ---------------------------------------------------------------
# Load emotion image..................
# Done !
# Number of emotion train data:  28709
# ---------------------------------------------------------------
# Load gender image...................
# Done !
# Number of gender train data:  30000
# ---------------------------------------------------------------
# Load age image..................
# Done !
# Number of age train data:  27353
# ---------------------------------------------------------------
# 1 1000 1000 1000
# 2 1000 1000 1000
# 3 1000 1000 1000
# 4 1000 1000 1000
# 5 1000 1000 1000
# 6 1000 1000 1000
# 7 1000 1000 1000
# 8 1000 1000 1000
# 9 1000 1000 1000
# 10 1000 1000 1000
# 11 1000 1000 1000
# 12 1000 1000 1000
# 13 1000 1000 1000
# 14 1000 1000 1000
# 15 1000 1000 1000
# 16 648 648 648

# %% [markdown]
# **Training model**

# %%
# %tensorflow_version 1.x

# %%
import tensorflow as tf 
print(tf.__version__)
# Out:
# 1.15.0

# %%
import model
session = tf.Session()
multitask_model = model.Multitask_BKNet(session)
multitask_model.train()
# Out:
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:11: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:55: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:98: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:70: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:95: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# (?, 24, 24, 32)
# (?, 12, 12, 64)
# (?, 6, 6, 128)
# (?, 3, 3, 256)
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:81: The name tf.nn.xw_plus_b is deprecated. Please use tf.compat.v1.nn.xw_plus_b instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:92: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:156: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:172: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:35: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# Load smile image...................
# Done !
# Number of smile train data:  3000
# ---------------------------------------------------------------
# Load emotion image..................
# Done !
# Number of emotion train data:  28709
# ---------------------------------------------------------------
# Load gender image...................
# Done !
# Number of gender train data:  30000
# ---------------------------------------------------------------
# Load age image..................
# Done !
# Number of age train data:  27353
# ---------------------------------------------------------------
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:41: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:41: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# Reading model parameters from %s /content/gdrive/My Drive/rubik_project/checkpoints/17012020/model.ckpt
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/rubik_project/checkpoints/17012020/model.ckpt
# Epoch:  0
# smile_loss: 0.31, emotion_loss: 1.17, gender_loss: 0.31, age_loss: 1.34, l2_loss: 0.63, total_loss: 3.76
#
# Smile task train accuracy: 100.0
# Emotion task train accuracy: 97.74983454665784
# Gender task train accuracy: 99.69
# Age task train accuracy: 91.14905129236281
# Epoch:  1
# smile_loss: 0.31, emotion_loss: 1.19, gender_loss: 0.35, age_loss: 1.31, l2_loss: 0.62, total_loss: 3.79
#
# Smile task train accuracy: 99.99666666666667
# Emotion task train accuracy: 97.79163328572922
# Gender task train accuracy: 99.63666666666666
# Age task train accuracy: 89.39421635652396
# Epoch:  2
# smile_loss: 0.31, emotion_loss: 1.23, gender_loss: 0.32, age_loss: 1.44, l2_loss: 0.62, total_loss: 3.93
#
# Smile task train accuracy: 99.94666666666666
# Emotion task train accuracy: 94.09941133442474
# Gender task train accuracy: 99.06666666666666
# Age task train accuracy: 81.1355244397324
# Epoch:  3
# smile_loss: 0.37, emotion_loss: 1.22, gender_loss: 0.38, age_loss: 1.63, l2_loss: 0.62, total_loss: 4.24
#
# Smile task train accuracy: 99.88
# Emotion task train accuracy: 89.4214357866871
# Gender task train accuracy: 98.51666666666667
# Age task train accuracy: 73.17661682447995
# Epoch:  4
# smile_loss: 0.31, emotion_loss: 1.38, gender_loss: 0.36, age_loss: 1.69, l2_loss: 0.63, total_loss: 4.37
#
# Smile task train accuracy: 99.71666666666667
# Emotion task train accuracy: 83.38848444738584
# Gender task train accuracy: 97.85666666666667
# Age task train accuracy: 64.91426900157205
# Epoch:  5
# smile_loss: 0.31, emotion_loss: 1.30, gender_loss: 0.33, age_loss: 1.66, l2_loss: 0.64, total_loss: 4.25
#
# Smile task train accuracy: 99.53333333333333
# Emotion task train accuracy: 77.94768191159567
# Gender task train accuracy: 97.50666666666666
# Age task train accuracy: 61.32051328921874
# Epoch:  6
# smile_loss: 0.40, emotion_loss: 1.33, gender_loss: 0.35, age_loss: 1.55, l2_loss: 0.64, total_loss: 4.27
#
# Smile task train accuracy: 99.06666666666666
# Emotion task train accuracy: 72.90745062523946
# Gender task train accuracy: 96.81666666666666
# Age task train accuracy: 55.42353672357694
# Epoch:  7
# smile_loss: 0.31, emotion_loss: 1.43, gender_loss: 0.41, age_loss: 1.71, l2_loss: 0.64, total_loss: 4.50
#
# Smile task train accuracy: 98.19333333333333
# Emotion task train accuracy: 65.0597373645895
# Gender task train accuracy: 95.00333333333333
# Age task train accuracy: 48.948926991554856
# Epoch:  8
# smile_loss: 0.36, emotion_loss: 1.70, gender_loss: 0.46, age_loss: 1.65, l2_loss: 0.65, total_loss: 4.81
#
# Smile task train accuracy: 97.31333333333333
# Emotion task train accuracy: 56.35863318123236
# Gender task train accuracy: 94.53666666666666
# Age task train accuracy: 42.29883376594889
# Epoch:  9
# smile_loss: 0.35, emotion_loss: 1.51, gender_loss: 0.37, age_loss: 2.05, l2_loss: 0.65, total_loss: 4.93
#
# Smile task train accuracy: 95.65666666666667
# Emotion task train accuracy: 50.58692396112717
# Gender task train accuracy: 92.65
# Age task train accuracy: 38.138412605564284
# Epoch:  10
# smile_loss: 0.31, emotion_loss: 1.66, gender_loss: 0.40, age_loss: 1.77, l2_loss: 0.64, total_loss: 4.79
#
# Smile task train accuracy: 94.02000000000001
# Emotion task train accuracy: 43.286077536660976
# Gender task train accuracy: 90.82000000000001
# Age task train accuracy: 34.01089460022666
# Epoch:  11
# smile_loss: 0.91, emotion_loss: 1.97, gender_loss: 0.51, age_loss: 1.82, l2_loss: 0.63, total_loss: 5.84
#
# Smile task train accuracy: 66.61666666666667
# Emotion task train accuracy: 25.828137517851545
# Gender task train accuracy: 76.32333333333334
# Age task train accuracy: 30.599934193689904
# Epoch:  12
# smile_loss: 0.88, emotion_loss: 2.13, gender_loss: 0.52, age_loss: 1.97, l2_loss: 0.60, total_loss: 6.10
#
# Smile task train accuracy: 45.9
# Emotion task train accuracy: 17.245463095196627
# Gender task train accuracy: 74.38
# Age task train accuracy: 30.629181442620553
# Epoch:  13
# smile_loss: 0.98, emotion_loss: 1.97, gender_loss: 0.88, age_loss: 1.88, l2_loss: 0.57, total_loss: 6.29
#
# Smile task train accuracy: 45.9
# Emotion task train accuracy: 17.262879236476365
# Gender task train accuracy: 74.39333333333333
# Age task train accuracy: 30.811976748437097
# Epoch:  14
# smile_loss: 0.84, emotion_loss: 1.88, gender_loss: 0.51, age_loss: 1.97, l2_loss: 0.54, total_loss: 5.74
#
# Smile task train accuracy: 45.9
# Emotion task train accuracy: 17.280295377756104
# Gender task train accuracy: 74.39666666666666
# Age task train accuracy: 30.757138156692136
# Epoch:  15
# smile_loss: 0.86, emotion_loss: 2.09, gender_loss: 0.50, age_loss: 2.03, l2_loss: 0.51, total_loss: 6.00
#
# Smile task train accuracy: 45.9
# Emotion task train accuracy: 16.63241492214985
# Gender task train accuracy: 74.38666666666667
# Age task train accuracy: 30.782729499506452
# Epoch:  16
# smile_loss: 0.86, emotion_loss: 1.90, gender_loss: 0.44, age_loss: 1.69, l2_loss: 0.48, total_loss: 5.38
#
# Smile task train accuracy: 45.9
# Emotion task train accuracy: 14.737538750914347
# Gender task train accuracy: 74.39666666666666
# Age task train accuracy: 30.76810587504113
# Epoch:  17
# smile_loss: 0.79, emotion_loss: 2.02, gender_loss: 0.63, age_loss: 1.79, l2_loss: 0.44, total_loss: 5.67
#
# Smile task train accuracy: 45.9
# Emotion task train accuracy: 16.96680483472082
# Gender task train accuracy: 74.39666666666666
# Age task train accuracy: 30.69133184659818
# Epoch:  18

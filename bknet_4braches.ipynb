# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd gdrive/My\ Drive/rubik_project
# Out:
# /content/gdrive/My Drive/rubik_project

# %%
# !nvidia-smi
# Out:
# Sat Jan 18 13:20:06 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.44       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import numpy as np
import cv2
import PIL
import imutils

# %%
import data_provider

dataset = data_provider.Dataset(data_type='public_test', batch_size=64)
print(len(dataset.all_data))

# assert len(dataset.all_data) == 15648

for i in range(len(dataset.all_data)):
    label = np.squeeze(np.array(dataset.all_data[i][1]))
    index = dataset.all_data[i][2]

    assert np.sum(label) == 1
    
    assert index == 1.0 or index == 2.0 or index == 3.0 or index == 4.0
    assert label.shape == (7,)
# Out:
# Load smile image...................
# Done !
# Number of smile train data:  3000
# ---------------------------------------------------------------
# Load emotion image..................
# Done !
# Number of emotion train data:  28709
# ---------------------------------------------------------------
# Load gender image...................
# Done !
# Number of gender train data:  30000
# ---------------------------------------------------------------
# Load age image..................
# Done !
# Number of age train data:  27353
# ---------------------------------------------------------------
# 15648

# %%
dataset = data_provider.Dataset(data_type='public_test', batch_size=1000)
cnt = 0
for batch_images, batch_labels, batch_indexes in dataset.gen():
    cnt += 1
    n = len(batch_images)
    m = len(batch_labels)
    k = len(batch_indexes)
    print(cnt, n, m, k)
    assert n == m == k
    if cnt % 16 == 0:
        assert n == 648
    else:
        assert n == 1000
# Out:
# Load smile image...................
# Done !
# Number of smile train data:  3000
# ---------------------------------------------------------------
# Load emotion image..................
# Done !
# Number of emotion train data:  28709
# ---------------------------------------------------------------
# Load gender image...................
# Done !
# Number of gender train data:  30000
# ---------------------------------------------------------------
# Load age image..................
# Done !
# Number of age train data:  27353
# ---------------------------------------------------------------
# 1 1000 1000 1000
# 2 1000 1000 1000
# 3 1000 1000 1000
# 4 1000 1000 1000
# 5 1000 1000 1000
# 6 1000 1000 1000
# 7 1000 1000 1000
# 8 1000 1000 1000
# 9 1000 1000 1000
# 10 1000 1000 1000
# 11 1000 1000 1000
# 12 1000 1000 1000
# 13 1000 1000 1000
# 14 1000 1000 1000
# 15 1000 1000 1000
# 16 648 648 648

# %% [markdown]
# **Training model**

# %%
# %tensorflow_version 1.x

# %%
import tensorflow as tf 
print(tf.__version__)
# Out:
# 1.15.0

# %%
import model
session = tf.Session()
multitask_model = model.Multitask_BKNet(session)
multitask_model.train()
# Out:
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:11: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:55: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:98: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:70: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:95: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# (?, 24, 24, 32)
# (?, 12, 12, 64)
# (?, 6, 6, 128)
# (?, 3, 3, 256)
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:81: The name tf.nn.xw_plus_b is deprecated. Please use tf.compat.v1.nn.xw_plus_b instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:92: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:156: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:172: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:35: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# Load smile image...................
# Done !
# Number of smile train data:  3000
# ---------------------------------------------------------------
# Load emotion image..................
# Done !
# Number of emotion train data:  28709
# ---------------------------------------------------------------
# Load gender image...................
# Done !
# Number of gender train data:  30000
# ---------------------------------------------------------------
# Load age image..................
# Done !
# Number of age train data:  27353
# ---------------------------------------------------------------
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:41: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/rubik_project/model.py:41: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# Reading model parameters from %s /content/gdrive/My Drive/rubik_project/checkpoints/17012020/model.ckpt
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/rubik_project/checkpoints/17012020/model.ckpt
# Epoch:  0
# smile_loss: 0.00, emotion_loss: 0.61, gender_loss: 0.08, age_loss: 1.19, l2_loss: 0.37, total_loss: 2.24
#
# Smile task train accuracy: 99.97
# Emotion task train accuracy: 71.16931972552162
# Gender task train accuracy: 96.51333333333334
# Age task train accuracy: 44.101195481300046
# Epoch:  1
# smile_loss: 0.00, emotion_loss: 0.55, gender_loss: 0.15, age_loss: 1.42, l2_loss: 0.37, total_loss: 2.49
#
# Smile task train accuracy: 99.99333333333334
# Emotion task train accuracy: 75.54773764324776
# Gender task train accuracy: 97.48333333333333
# Age task train accuracy: 46.33861002449457
# Epoch:  2
# smile_loss: 0.00, emotion_loss: 0.73, gender_loss: 0.07, age_loss: 1.26, l2_loss: 0.38, total_loss: 2.45
#
# Smile task train accuracy: 99.99
# Emotion task train accuracy: 79.37232226827824
# Gender task train accuracy: 97.98333333333333
# Age task train accuracy: 48.791723028552624
# Epoch:  3
# smile_loss: 0.00, emotion_loss: 0.26, gender_loss: 0.01, age_loss: 1.40, l2_loss: 0.39, total_loss: 2.06
#
# Smile task train accuracy: 99.99333333333334
# Emotion task train accuracy: 82.4863283290954
# Gender task train accuracy: 98.46666666666667
# Age task train accuracy: 51.051073008445144
# Epoch:  4
# smile_loss: 0.00, emotion_loss: 0.65, gender_loss: 0.05, age_loss: 1.06, l2_loss: 0.41, total_loss: 2.17
#
# Smile task train accuracy: 99.99
# Emotion task train accuracy: 84.99773590163363
# Gender task train accuracy: 98.79
# Age task train accuracy: 53.56999232259716
# Epoch:  5
# smile_loss: 0.00, emotion_loss: 0.62, gender_loss: 0.17, age_loss: 1.31, l2_loss: 0.42, total_loss: 2.53
#
# Smile task train accuracy: 99.99666666666667
# Emotion task train accuracy: 87.46386150684454
# Gender task train accuracy: 99.08
# Age task train accuracy: 56.831060578364344
# Epoch:  6
# smile_loss: 0.00, emotion_loss: 0.50, gender_loss: 0.01, age_loss: 1.13, l2_loss: 0.44, total_loss: 2.08
#
# Smile task train accuracy: 99.99666666666667
# Emotion task train accuracy: 88.92681737434253
# Gender task train accuracy: 99.12666666666667
# Age task train accuracy: 59.697290973567796
# Epoch:  7
# smile_loss: 0.42, emotion_loss: 0.39, gender_loss: 0.02, age_loss: 0.96, l2_loss: 0.46, total_loss: 2.24
#
# Smile task train accuracy: 99.98666666666666
# Emotion task train accuracy: 90.29572607892995
# Gender task train accuracy: 99.16
# Age task train accuracy: 61.938361422878664
# Epoch:  8
# smile_loss: 0.00, emotion_loss: 0.25, gender_loss: 0.09, age_loss: 0.78, l2_loss: 0.47, total_loss: 1.60
#
# Smile task train accuracy: 99.98333333333333
# Emotion task train accuracy: 91.69946706607685
# Gender task train accuracy: 99.29
# Age task train accuracy: 65.8319014367711
# Epoch:  9
# smile_loss: 0.00, emotion_loss: 0.37, gender_loss: 0.08, age_loss: 1.28, l2_loss: 0.49, total_loss: 2.21
#
# Smile task train accuracy: 99.99
# Emotion task train accuracy: 92.57375735831968
# Gender task train accuracy: 99.37333333333333
# Age task train accuracy: 68.1716813512229
# Epoch:  10
# smile_loss: 0.00, emotion_loss: 0.54, gender_loss: 0.08, age_loss: 1.12, l2_loss: 0.50, total_loss: 2.24
#
# Smile task train accuracy: 99.98666666666666
# Emotion task train accuracy: 93.50726253091365
# Gender task train accuracy: 99.42
# Age task train accuracy: 70.7235038204219
# Epoch:  11
# smile_loss: 0.00, emotion_loss: 0.22, gender_loss: 0.16, age_loss: 0.79, l2_loss: 0.52, total_loss: 1.69
#
# Smile task train accuracy: 99.99666666666667
# Emotion task train accuracy: 94.23177400815077
# Gender task train accuracy: 99.41666666666666
# Age task train accuracy: 73.75424999086023
# Epoch:  12
# smile_loss: 0.00, emotion_loss: 0.06, gender_loss: 0.04, age_loss: 1.06, l2_loss: 0.53, total_loss: 1.69
#
# Smile task train accuracy: 99.99333333333334
# Emotion task train accuracy: 94.91100351806054
# Gender task train accuracy: 99.53999999999999
# Age task train accuracy: 75.65532117135231
# Epoch:  13
# smile_loss: 0.00, emotion_loss: 0.12, gender_loss: 0.05, age_loss: 0.83, l2_loss: 0.55, total_loss: 1.55
#
# Smile task train accuracy: 99.99666666666667
# Emotion task train accuracy: 95.4927026368038
# Gender task train accuracy: 99.51666666666667
# Age task train accuracy: 78.83595949256022
# Epoch:  14
# smile_loss: 0.00, emotion_loss: 0.14, gender_loss: 0.00, age_loss: 0.53, l2_loss: 0.56, total_loss: 1.24
#
# Smile task train accuracy: 99.98666666666666
# Emotion task train accuracy: 95.7051795604166
# Gender task train accuracy: 99.56666666666666
# Age task train accuracy: 80.84670785654224
# Epoch:  15
# smile_loss: 0.00, emotion_loss: 0.34, gender_loss: 0.01, age_loss: 0.48, l2_loss: 0.58, total_loss: 1.40
#
# Smile task train accuracy: 99.97333333333333
# Emotion task train accuracy: 95.91417325577345
# Gender task train accuracy: 99.55333333333334
# Age task train accuracy: 82.4260592987972
# Epoch:  16
# smile_loss: 0.00, emotion_loss: 0.19, gender_loss: 0.01, age_loss: 0.51, l2_loss: 0.59, total_loss: 1.30
#
# Smile task train accuracy: 99.98333333333333
# Emotion task train accuracy: 96.33216064648717
# Gender task train accuracy: 99.55666666666667
# Age task train accuracy: 84.10046430007677
# Epoch:  17
# smile_loss: 0.11, emotion_loss: 0.28, gender_loss: 0.00, age_loss: 0.86, l2_loss: 0.60, total_loss: 1.85
#
# Smile task train accuracy: 99.98333333333333
# Emotion task train accuracy: 96.52722142882023
# Gender task train accuracy: 99.53999999999999
# Age task train accuracy: 85.17530069827806
# Epoch:  18
# smile_loss: 0.00, emotion_loss: 0.14, gender_loss: 0.01, age_loss: 0.67, l2_loss: 0.61, total_loss: 1.43
#
# Smile task train accuracy: 99.99333333333334
# Emotion task train accuracy: 96.60385245045107
# Gender task train accuracy: 99.57333333333334
# Age task train accuracy: 86.31228750045699
# Epoch:  19
# smile_loss: 0.00, emotion_loss: 0.02, gender_loss: 0.00, age_loss: 0.69, l2_loss: 0.62, total_loss: 1.34
#
# Smile task train accuracy: 99.99666666666667
# Emotion task train accuracy: 97.02183984116479
# Gender task train accuracy: 99.59333333333333
# Age task train accuracy: 87.97572478338756
# Epoch:  20
# smile_loss: 0.00, emotion_loss: 0.14, gender_loss: 0.01, age_loss: 0.25, l2_loss: 0.63, total_loss: 1.03
#
# Smile task train accuracy: 99.99666666666667
# Emotion task train accuracy: 96.78498031976035
# Gender task train accuracy: 99.63
# Age task train accuracy: 88.55335794976786
# Epoch:  21
# smile_loss: 0.00, emotion_loss: 0.12, gender_loss: 0.00, age_loss: 0.29, l2_loss: 0.65, total_loss: 1.06
#
# Smile task train accuracy: 99.99
# Emotion task train accuracy: 97.25173290605733
# Gender task train accuracy: 99.57666666666667
# Age task train accuracy: 89.42346360545461
# Epoch:  22
